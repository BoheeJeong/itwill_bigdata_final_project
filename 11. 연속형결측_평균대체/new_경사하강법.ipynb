# %% [markdown]
# # 11. 연속형결측_평균대체 - 경사하강법(SGDClassifier)
#
# 3번과 동일한 데이터/분할. 연속형 결측만 **평균(mean)** 대체.

# %%
import sys
import os
PROJECT_ROOT = r"c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project"
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)
from scenario_runner import run_model
from sklearn.linear_model import SGDClassifier

estimator = SGDClassifier(random_state=52, loss="log_loss", max_iter=2000)
SAVE_DIR = os.path.join(PROJECT_ROOT, "11. 연속형결측_평균대체", "results")
metrics = run_model(scenario="mean", estimator=estimator, save_dir=SAVE_DIR, save_name="new_경사하강법")
metrics
# Out:
# [mean] Saved result to: c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project\11. 연속형결측_평균대체\results\new_경사하강법.pkl
# metrics: {'scenario': 'mean', 'accuracy': 0.7907590759075908, 'precision': 0.7055084745762712, 'recall': 0.6516634050880626, 'f1': 0.6775178026449644, 'auc': 0.8520809131380545, 'log_loss': 0.5428105019524926}
# C:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# {'scenario': 'mean',
#  'accuracy': 0.7907590759075908,
#  'precision': 0.7055084745762712,
#  'recall': 0.6516634050880626,
#  'f1': 0.6775178026449644,
#  'auc': 0.8520809131380545,
#  'log_loss': 0.5428105019524926}
