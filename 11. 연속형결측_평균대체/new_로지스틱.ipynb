# %% [markdown]
# # 11. 연속형결측_평균대체 - 로지스틱 회귀
#
# 3번(결측 제거 없음, 로그 없음)과 동일한 데이터/분할. 연속형 결측만 **평균(mean)** 대체.

# %%
import sys
import os
PROJECT_ROOT = r"c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project"
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)
from scenario_runner import run_model
from sklearn.linear_model import LogisticRegression

estimator = LogisticRegression(random_state=52, max_iter=1000, C=0.1, class_weight="balanced")
SAVE_DIR = os.path.join(PROJECT_ROOT, "11. 연속형결측_평균대체", "results")
metrics = run_model(scenario="mean", estimator=estimator, save_dir=SAVE_DIR, save_name="new_로지스틱")
metrics
# Out:
# [mean] Saved result to: c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project\11. 연속형결측_평균대체\results\new_로지스틱.pkl
# metrics: {'scenario': 'mean', 'accuracy': 0.8257425742574257, 'precision': 0.7021276595744681, 'recall': 0.8395303326810176, 'f1': 0.7647058823529411, 'auc': 0.9051367913863138, 'log_loss': 0.39644658781482706}
# C:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# {'scenario': 'mean',
#  'accuracy': 0.8257425742574257,
#  'precision': 0.7021276595744681,
# ...
