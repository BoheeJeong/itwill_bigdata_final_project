# %% [markdown]
# # 13. 연속형결측_Iterative대체 - 로지스틱 회귀
#
# 3번과 동일. 연속형 결측 **IterativeImputer(MICE)**.

# %%
import sys
import os
PROJECT_ROOT = r"c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project"
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)
from scenario_runner import run_model
from sklearn.linear_model import LogisticRegression

estimator = LogisticRegression(random_state=52, max_iter=1000, C=0.1, class_weight="balanced")
SAVE_DIR = os.path.join(PROJECT_ROOT, "13. 연속형결측_Iterative대체", "results")
metrics = run_model(scenario="iterative", estimator=estimator, save_dir=SAVE_DIR, save_name="new_로지스틱")
metrics
# Out:
# [iterative] Saved result to: c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project\13. 연속형결측_Iterative대체\results\new_로지스틱.pkl
# metrics: {'scenario': 'iterative', 'accuracy': 0.801980198019802, 'precision': 0.6698872785829307, 'recall': 0.8140900195694716, 'f1': 0.734982332155477, 'auc': 0.8777765649729847, 'log_loss': 0.4408206730358648}
# C:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# {'scenario': 'iterative',
#  'accuracy': 0.801980198019802,
#  'precision': 0.6698872785829307,
# ...
