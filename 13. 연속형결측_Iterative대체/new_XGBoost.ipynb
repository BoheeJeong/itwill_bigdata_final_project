# %% [markdown]
# # 13. 연속형결측_Iterative대체 - XGBoost
#
# 3번과 동일. 연속형 결측 **IterativeImputer**.

# %%
import sys
import os
PROJECT_ROOT = r"c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project"
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)
from scenario_runner import run_model
from xgboost import XGBClassifier

estimator = XGBClassifier(random_state=52, eval_metric="logloss")
SAVE_DIR = os.path.join(PROJECT_ROOT, "13. 연속형결측_Iterative대체", "results")
metrics = run_model(scenario="iterative", estimator=estimator, save_dir=SAVE_DIR, save_name="new_XGBoost")
metrics
# Out:
# [iterative] Saved result to: c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project\13. 연속형결측_Iterative대체\results\new_XGBoost.pkl
# metrics: {'scenario': 'iterative', 'accuracy': 0.8422442244224423, 'precision': 0.7821576763485477, 'recall': 0.7377690802348337, 'f1': 0.7593152064451159, 'auc': 0.9171162707292162, 'log_loss': 0.3907710693308978}
# C:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# {'scenario': 'iterative',
#  'accuracy': 0.8422442244224423,
#  'precision': 0.7821576763485477,
#  'recall': 0.7377690802348337,
#  'f1': 0.7593152064451159,
#  'auc': 0.9171162707292162,
#  'log_loss': 0.3907710693308978}
