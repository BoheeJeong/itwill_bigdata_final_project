# %% [markdown]
# # 13. 연속형결측_Iterative대체 - CatBoost
#
# 3번과 동일. 연속형 결측 **IterativeImputer**.

# %%
import sys
import os
PROJECT_ROOT = r"c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project"
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)
from scenario_runner import run_model
from catboost import CatBoostClassifier

estimator = CatBoostClassifier(random_state=52, verbose=0)
SAVE_DIR = os.path.join(PROJECT_ROOT, "13. 연속형결측_Iterative대체", "results")
metrics = run_model(scenario="iterative", estimator=estimator, save_dir=SAVE_DIR, save_name="new_CatBoost")
metrics
# Out:
# [iterative] Saved result to: c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project\13. 연속형결측_Iterative대체\results\new_CatBoost.pkl
# metrics: {'scenario': 'iterative', 'accuracy': 0.8468646864686469, 'precision': 0.7876288659793814, 'recall': 0.7475538160469667, 'f1': 0.7670682730923695, 'auc': 0.9156622044113175, 'log_loss': 0.3457941150807438}
# C:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# {'scenario': 'iterative',
#  'accuracy': 0.8468646864686469,
#  'precision': 0.7876288659793814,
#  'recall': 0.7475538160469667,
#  'f1': 0.7670682730923695,
#  'auc': 0.9156622044113175,
#  'log_loss': 0.3457941150807438}
