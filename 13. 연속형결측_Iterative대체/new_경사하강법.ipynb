# %% [markdown]
# # 13. 연속형결측_Iterative대체 - 경사하강법
#
# 3번과 동일. 연속형 결측 **IterativeImputer**.

# %%
import sys
import os
PROJECT_ROOT = r"c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project"
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)
from scenario_runner import run_model
from sklearn.linear_model import SGDClassifier

estimator = SGDClassifier(random_state=52, loss="log_loss", max_iter=2000)
SAVE_DIR = os.path.join(PROJECT_ROOT, "13. 연속형결측_Iterative대체", "results")
metrics = run_model(scenario="iterative", estimator=estimator, save_dir=SAVE_DIR, save_name="new_경사하강법")
metrics
# Out:
# [iterative] Saved result to: c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project\13. 연속형결측_Iterative대체\results\new_경사하강법.pkl
# metrics: {'scenario': 'iterative', 'accuracy': 0.7722772277227723, 'precision': 0.6828193832599119, 'recall': 0.6066536203522505, 'f1': 0.6424870466321243, 'auc': 0.839220417741948, 'log_loss': 0.5263227923836378}
# C:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# {'scenario': 'iterative',
#  'accuracy': 0.7722772277227723,
#  'precision': 0.6828193832599119,
#  'recall': 0.6066536203522505,
#  'f1': 0.6424870466321243,
#  'auc': 0.839220417741948,
#  'log_loss': 0.5263227923836378}
