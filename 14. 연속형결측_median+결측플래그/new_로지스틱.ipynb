# %% [markdown]
# # 14. 연속형결측_median+결측플래그 - 로지스틱 회귀
#
# 3번과 동일. 연속형 결측 **중앙값 대체 + 결측 여부 0/1 컬럼** 추가.

# %%
import sys
import os
PROJECT_ROOT = r"c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project"
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)
from scenario_runner import run_model
from sklearn.linear_model import LogisticRegression

estimator = LogisticRegression(random_state=52, max_iter=1000, C=0.1, class_weight="balanced")
SAVE_DIR = os.path.join(PROJECT_ROOT, "14. 연속형결측_median+결측플래그", "results")
metrics = run_model(scenario="median_flag", estimator=estimator, save_dir=SAVE_DIR, save_name="new_로지스틱")
metrics
# Out:
# [median_flag] Saved result to: c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project\14. 연속형결측_median+결측플래그\results\new_로지스틱.pkl
# metrics: {'scenario': 'median_flag', 'accuracy': 0.8996699669966997, 'precision': 0.8342644320297952, 'recall': 0.8767123287671232, 'f1': 0.8549618320610687, 'auc': 0.9526726752481268, 'log_loss': 0.2822792745159345}
# C:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# {'scenario': 'median_flag',
#  'accuracy': 0.8996699669966997,
#  'precision': 0.8342644320297952,
# ...
