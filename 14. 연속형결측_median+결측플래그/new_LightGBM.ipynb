# %% [markdown]
# # 14. 연속형결측_median+결측플래그 - LightGBM
#
# 3번과 동일. 연속형 **median + 결측 플래그**.

# %%
import sys
import os
PROJECT_ROOT = r"c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project"
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)
from scenario_runner import run_model
from lightgbm import LGBMClassifier

estimator = LGBMClassifier(random_state=52, verbose=-1)
SAVE_DIR = os.path.join(PROJECT_ROOT, "14. 연속형결측_median+결측플래그", "results")
metrics = run_model(scenario="median_flag", estimator=estimator, save_dir=SAVE_DIR, save_name="new_LightGBM")
metrics
# Out:
# c:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# invalid literal for int() with base 10: ''
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\externals\loky\backend\context.py", line 268, in _count_physical_cores
#     cpu_count_physical = sum(map(int, cpu_info))
#                          ^^^^^^^^^^^^^^^^^^^^^^^
# c:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# c:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [median_flag] Saved result to: c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project\14. 연속형결측_median+결측플래그\results\new_LightGBM.pkl
# metrics: {'scenario': 'median_flag', 'accuracy': 0.9108910891089109, 'precision': 0.8805668016194332, 'recall': 0.8512720156555773, 'f1': 0.8656716417910447, 'auc': 0.958882668932879, 'log_loss': 0.24720933389954527}
# {'scenario': 'median_flag',
#  'accuracy': 0.9108910891089109,
#  'precision': 0.8805668016194332,
#  'recall': 0.8512720156555773,
#  'f1': 0.8656716417910447,
#  'auc': 0.958882668932879,
#  'log_loss': 0.24720933389954527}
