# %% [markdown]
# # 14. 연속형결측_median+결측플래그 - CatBoost
#
# 3번과 동일. 연속형 **median + 결측 플래그**.

# %%
import sys
import os
PROJECT_ROOT = r"c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project"
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)
from scenario_runner import run_model
from catboost import CatBoostClassifier

estimator = CatBoostClassifier(random_state=52, verbose=0)
SAVE_DIR = os.path.join(PROJECT_ROOT, "14. 연속형결측_median+결측플래그", "results")
metrics = run_model(scenario="median_flag", estimator=estimator, save_dir=SAVE_DIR, save_name="new_CatBoost")
metrics
# Out:
# [median_flag] Saved result to: c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project\14. 연속형결측_median+결측플래그\results\new_CatBoost.pkl
# metrics: {'scenario': 'median_flag', 'accuracy': 0.9062706270627062, 'precision': 0.8851774530271399, 'recall': 0.8297455968688845, 'f1': 0.8565656565656565, 'auc': 0.9610988531198102, 'log_loss': 0.23921043575992798}
# C:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# {'scenario': 'median_flag',
#  'accuracy': 0.9062706270627062,
#  'precision': 0.8851774530271399,
#  'recall': 0.8297455968688845,
#  'f1': 0.8565656565656565,
#  'auc': 0.9610988531198102,
#  'log_loss': 0.23921043575992798}
