# %% [markdown]
# # 12. 연속형결측_KNN대체 - XGBoost
#
# 3번과 동일. 연속형 결측 **KNNImputer**.

# %%
import sys
import os
PROJECT_ROOT = r"c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project"
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)
from scenario_runner import run_model
from xgboost import XGBClassifier

estimator = XGBClassifier(random_state=52, eval_metric="logloss")
SAVE_DIR = os.path.join(PROJECT_ROOT, "12. 연속형결측_KNN대체", "results")
metrics = run_model(scenario="knn", estimator=estimator, save_dir=SAVE_DIR, save_name="new_XGBoost")
metrics
# Out:
# C:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [knn] Saved result to: c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project\12. 연속형결측_KNN대체\results\new_XGBoost.pkl
# metrics: {'scenario': 'knn', 'accuracy': 0.8521452145214522, 'precision': 0.8086021505376344, 'recall': 0.735812133072407, 'f1': 0.7704918032786885, 'auc': 0.9204376232837729, 'log_loss': 0.375910765382218}
# C:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# {'scenario': 'knn',
#  'accuracy': 0.8521452145214522,
#  'precision': 0.8086021505376344,
#  'recall': 0.735812133072407,
#  'f1': 0.7704918032786885,
#  'auc': 0.9204376232837729,
#  'log_loss': 0.375910765382218}
