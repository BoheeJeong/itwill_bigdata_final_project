# %% [markdown]
# # 12. 연속형결측_KNN대체 - 랜덤포레스트
#
# 3번과 동일. 연속형 결측 **KNNImputer**.

# %%
import sys
import os
PROJECT_ROOT = r"c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project"
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)
from scenario_runner import run_model
from sklearn.ensemble import RandomForestClassifier

estimator = RandomForestClassifier(random_state=52)
SAVE_DIR = os.path.join(PROJECT_ROOT, "12. 연속형결측_KNN대체", "results")
metrics = run_model(scenario="knn", estimator=estimator, save_dir=SAVE_DIR, save_name="new_랜덤포레스트")
metrics
# Out:
# C:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [knn] Saved result to: c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project\12. 연속형결측_KNN대체\results\new_랜덤포레스트.pkl
# metrics: {'scenario': 'knn', 'accuracy': 0.8303630363036304, 'precision': 0.8324607329842932, 'recall': 0.6223091976516634, 'f1': 0.7122060470324748, 'auc': 0.8971277317345102, 'log_loss': 0.4023739079365993}
# C:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# {'scenario': 'knn',
#  'accuracy': 0.8303630363036304,
#  'precision': 0.8324607329842932,
# ...
