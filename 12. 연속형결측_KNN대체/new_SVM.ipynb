# %% [markdown]
# # 12. 연속형결측_KNN대체 - SVM
#
# 3번과 동일. 연속형 결측 **KNNImputer**.

# %%
import sys
import os
PROJECT_ROOT = r"c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project"
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)
from scenario_runner import run_model
from sklearn.svm import SVC

estimator = SVC(probability=True, random_state=52)
SAVE_DIR = os.path.join(PROJECT_ROOT, "12. 연속형결측_KNN대체", "results")
metrics = run_model(scenario="knn", estimator=estimator, save_dir=SAVE_DIR, save_name="new_SVM")
metrics
# Out:
# C:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# C:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [knn] Saved result to: c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project\12. 연속형결측_KNN대체\results\new_SVM.pkl
# metrics: {'scenario': 'knn', 'accuracy': 0.829042904290429, 'precision': 0.8014354066985646, 'recall': 0.6555772994129159, 'f1': 0.721205597416577, 'auc': 0.8926622278011243, 'log_loss': 0.38794850623617694}
# {'scenario': 'knn',
#  'accuracy': 0.829042904290429,
#  'precision': 0.8014354066985646,
#  'recall': 0.6555772994129159,
#  'f1': 0.721205597416577,
#  'auc': 0.8926622278011243,
#  'log_loss': 0.38794850623617694}
