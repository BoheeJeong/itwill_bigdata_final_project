# %% [markdown]
# # 12. 연속형결측_KNN대체 - 로지스틱 회귀
#
# 3번과 동일한 데이터/분할. 연속형 결측만 **KNNImputer** 대체.

# %%
import sys
import os
PROJECT_ROOT = r"c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project"
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)
from scenario_runner import run_model
from sklearn.linear_model import LogisticRegression

estimator = LogisticRegression(random_state=52, max_iter=1000, C=0.1, class_weight="balanced")
SAVE_DIR = os.path.join(PROJECT_ROOT, "12. 연속형결측_KNN대체", "results")
metrics = run_model(scenario="knn", estimator=estimator, save_dir=SAVE_DIR, save_name="new_로지스틱")
metrics
# Out:
# C:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [knn] Saved result to: c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project\12. 연속형결측_KNN대체\results\new_로지스틱.pkl
# metrics: {'scenario': 'knn', 'accuracy': 0.7986798679867987, 'precision': 0.6672077922077922, 'recall': 0.8043052837573386, 'f1': 0.7293700088731144, 'auc': 0.8804001216269951, 'log_loss': 0.4371209197767608}
# C:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# {'scenario': 'knn',
#  'accuracy': 0.7986798679867987,
#  'precision': 0.6672077922077922,
# ...
