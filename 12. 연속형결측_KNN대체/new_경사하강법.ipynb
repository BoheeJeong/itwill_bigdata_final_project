# %% [markdown]
# # 12. 연속형결측_KNN대체 - 경사하강법
#
# 3번과 동일. 연속형 결측 **KNNImputer**.

# %%
import sys
import os
PROJECT_ROOT = r"c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project"
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)
from scenario_runner import run_model
from sklearn.linear_model import SGDClassifier

estimator = SGDClassifier(random_state=52, loss="log_loss", max_iter=2000)
SAVE_DIR = os.path.join(PROJECT_ROOT, "12. 연속형결측_KNN대체", "results")
metrics = run_model(scenario="knn", estimator=estimator, save_dir=SAVE_DIR, save_name="new_경사하강법")
metrics
# Out:
# C:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [knn] Saved result to: c:\itwill_bigdata_final_project-main\itwill_bigdata_final_project\12. 연속형결측_KNN대체\results\new_경사하강법.pkl
# metrics: {'scenario': 'knn', 'accuracy': 0.7907590759075908, 'precision': 0.7298578199052133, 'recall': 0.6027397260273972, 'f1': 0.6602357984994641, 'auc': 0.8516832864237764, 'log_loss': 0.5440577968696138}
# C:\Users\itwill\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0, 18, 38] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# {'scenario': 'knn',
#  'accuracy': 0.7907590759075908,
#  'precision': 0.7298578199052133,
#  'recall': 0.6027397260273972,
#  'f1': 0.6602357984994641,
#  'auc': 0.8516832864237764,
#  'log_loss': 0.5440577968696138}
