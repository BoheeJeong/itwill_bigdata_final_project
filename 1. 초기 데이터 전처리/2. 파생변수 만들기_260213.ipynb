# %% [markdown]
# # 260213 | 데이터 분석에 필요한 파생 변수 생성

# %% [markdown]
# ### 라이브러리 참조

# %%
from pandas import DataFrame, read_csv, read_excel

# %% [markdown]
# #### 필요한 컬럼만 가져온 데이터 프레임 불러오기

# %%
lt09_only_needed_raw_data_260212 = read_csv(
    'C:/itwill_bigdata_final_project-main/itwill_bigdata_final_project/1. 초기 데이터 전처리/lt09_only_needed_raw_data_260212.csv',
    encoding='utf-8'
)


# 확인
lt09_only_needed_raw_data_260212
# Out:
#       w09_fam1  w09_fam2  w09hhsize  w09edu  w09gender1  w09a002_age  \
# 0            1         2          2       4           5           67
# 1            1         2          2       4           1           68
# 2            1         2          2       1           1           80
# 3            1         2          2       1           5           76
# 4            1         1          1       1           5           78
# ...        ...       ...        ...     ...         ...          ...
# 6052         1         2          2       3           5           59
# 6053         1         1          1       3           5           60
# 6054         2         5          3       2           1           60
# 6055         1         2          2       3           1           60
# 6056         1         2          2       3           5           59
#
#       w09marital  w09year2  w09edu_s  w09ecoact_s  w09enu_type  w09ba003  \
# ...

# %% [markdown]
# #### 만들어야할 파생 변수 정리
# 1. 독립변수 | 주관적 인식 | 주관적 기대감 : 나이대별로 분산되어 있는 컬럼 하나의 값으로 취합
# 2. 독립변수 | 정신건강 | CESD-10 : 우울증 여부 판단 점수 집계
# 3. 종속변수 | 고용 | 경활상태 : 취업자 / 실업자 / 비경활 구분
# 4. 종속변수 | 고용 | 임금근로 여부 : 원자료 데이터 확인 필요!!!!!!!!!!!!!
